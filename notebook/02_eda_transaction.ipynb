# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
plt.style.use("seaborn-v0_8-darkgrid")

# path ke file data (tanpa import package src)
DATA_DIR = Path("../data/interim")
TRAIN_PATH = DATA_DIR / "train_merged.parquet"

# %% [markdown]
# # 02 - EDA: Transaction Features
#
# ## Objective
# - Eksplorasi fitur-fitur pada tabel transaksi
# - Memahami pola TransactionDT dan mengekstrak fitur waktu yang berguna
# - Menganalisis fitur kartu (card1–card6)
# - Melihat distribusi count features (C1–C14) dan V-features (Vesta)

# %%
# muat data yang sudah digabung

train = pd.read_parquet(TRAIN_PATH)
print(f'Data loaded: {train.shape}')
# Out:
# Data loaded: (590540, 434)

# %%
print(f"Columns: {len(train.columns)}")
print(f"Transaction data: {len(train[train['isFraud'] == 0]):,} legitimate, {len(train[train['isFraud'] == 1]):,} fraudulent")
# Out:
# Columns: 434
# Transaction data: 569,877 legitimate, 20,663 fraudulent

# %% [markdown]
# ## TransactionDT - Fitur Waktu
#
# TransactionDT bukan timestamp nyata, melainkan **detik yang berlalu sejak titik referensi tertentu**.
#
# - Range: 0 hingga ~31 juta detik
# - Mencakup sekitar 6 bulan aktivitas transaksi di data training

# %%
# fitur waktu transaksi

# konstanta konversi waktu
SECOND_PER_HOUR = 3600
SECOND_PER_DAY = 86400

# ekstrak fitur waktu dari TransactionDT
train['hour'] = (train['TransactionDT'] // SECOND_PER_HOUR) % 24
train['day_of_week'] = (train['TransactionDT'] // SECOND_PER_DAY) % 7
train['day'] = (train['TransactionDT'] // SECOND_PER_DAY)

print('TransactionDT Statistics :')
print(f'Min : {train['TransactionDT'].min():,} second')
print(f'Max :{train['TransactionDT'].max():,} second')
print(f'Range : {train['TransactionDT'].max() // SECOND_PER_DAY } days')

print('\nExtract Features')
print(f'Hour Range {train['hour'].min()} - {train['hour'].max()}')
print(f'days in data {train['day'].nunique()}')
# Out:
# TransactionDT Statistics :
# Min : 86,400 second
# Max :15,811,131 second
# Range : 182 days
#
# Extract Features
# Hour Range 0 - 23
# days in data 182

# %%
# fraud rate per jam

fraud_by_hour = train.groupby('hour').agg({
    'isFraud' : ['sum', 'mean', 'count']
})
fraud_by_hour.columns = ['fraud_count', 'fraud_rate', 'total_count']
fraud_by_hour['fraud_rate'] *= 100

# plot fraud rate per jam
fig, axes = plt.subplots(1,2, figsize=(14,5))

# jumlah transaksi per jam
axes[0].bar(fraud_by_hour.index, fraud_by_hour['total_count'])
axes[0].set_title('Transaction per Hour')
axes[0].set_xlabel('Hour of day')
axes[0].set_ylabel('Count')

# fraud rate per jam
axes[1].bar(fraud_by_hour.index, fraud_by_hour['fraud_rate'], color='#e74c3c')
axes[1].set_title('Fraud Rate per Hour')
axes[1].set_xlabel('Hour of day')
axes[1].set_ylabel('Fraud Rate (%)')
axes[1].axhline(y=train['isFraud'].mean()*100, color='black', linestyle='--', label='Overal Rate')
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# fraud rate per hari dalam seminggu

fraud_by_dow = train.groupby('day_of_week')['isFraud'].mean()* 100
dow_name = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

fig, ax = plt.subplots(figsize=(10,6))
ax.bar(range(7), fraud_by_dow.values)
ax.set_xticks(range(7))
ax.set_xticklabels(dow_name)
ax.set_xlabel('Day of Week')
ax.set_ylabel('Fraud Rate (%)')
ax.axhline(y=train['isFraud'].mean()*100, color='black', linestyle='--', label='Overall Rate')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Fitur Kartu (card1–card6)
#
# Masing-masing kolom kartu merepresentasikan atribut berbeda — dari BIN issuer hingga jaringan dan tipe kartu. Kita eksplorasi nilai aktualnya untuk memahami makna tiap kolom.

# %%
# identifikasi kolom kartu yang tersedia

card_cols = ['card1', 'card2', 'card3', 'card4', 'card5', 'card6']

for col in card_cols:
    nunique = train[col].nunique()
    missing = train[col].isnull().sum() / len(train) * 100
    dtype = train[col].dtype
    print(f'{col}: {nunique} unique, {missing:.1f}% missing, type={dtype}')
# Out:
# card1: 13553 unique, 0.0% missing, type=int16
# card2: 500 unique, 1.5% missing, type=float32
# card3: 114 unique, 0.3% missing, type=float32
# card4: 4 unique, 0.3% missing, type=category
# card5: 119 unique, 0.7% missing, type=float32
# card6: 4 unique, 0.3% missing, type=category

# %%
# card4 dan card6 punya nilai string yang terlihat
print("card4:", train["card4"].dropna().unique())
print("card6:", train["card6"].dropna().unique())

# cek apakah card1 punya hubungan 1:1 dengan jaringan kartu
for c1 in train["card1"].value_counts().head(5).index:
    nets = train.loc[train["card1"]==c1,"card4"].value_counts(dropna=False)
    print(f"card1={c1}: {dict(nets)}")
# Out:
# card4: ['discover', 'mastercard', 'visa', 'american express']
# Categories (4, str): ['american express', 'discover', 'mastercard', 'visa']
# card6: ['credit', 'debit', 'debit or credit', 'charge card']
# Categories (4, str): ['charge card', 'credit', 'debit', 'debit or credit']
# card1=7919: {'mastercard': np.int64(14891), nan: np.int64(41), 'american express': np.int64(0), 'discover': np.int64(0), 'visa': np.int64(0)}
# card1=9500: {'visa': np.int64(14112), nan: np.int64(50), 'american express': np.int64(0), 'discover': np.int64(0), 'mastercard': np.int64(0)}
# card1=15885: {'visa': np.int64(10332), nan: np.int64(29), 'american express': np.int64(0), 'discover': np.int64(0), 'mastercard': np.int64(0)}
# card1=17188: {'visa': np.int64(10312), nan: np.int64(32), 'american express': np.int64(0), 'discover': np.int64(0), 'mastercard': np.int64(0)}
# ...

# %%
# fraud rate berdasarkan kartu

# card4 dan card6 (kategorikal, punya label string)
for col in ['card4', 'card6']:
    fraud_rate = train.groupby(col)['isFraud'].agg(['mean', 'count'])
    fraud_rate['mean'] *= 100
    fraud_rate.columns = ['fraud_rate', 'count']

    print(f'\n{col} fraud rate :')
    print(fraud_rate.sort_values('fraud_rate', ascending=False))

    # visualisasi fraud rate per kategori
    fig, ax = plt.subplots(figsize=(10,5))
    fraud_rate['fraud_rate'].sort_values(ascending=False).plot(kind='bar', ax=ax)
    ax.set_title(f'Fraud by {col}')
    ax.set_ylabel('fraud rate %')
    ax.axhline(y=train['isFraud'].mean()*100, color='black', linestyle='--', label='overal Rate')
    ax.legend()
    plt.xticks(rotation=0)
    plt.tight_layout()
    plt.show()
# Out:
# card4 fraud rate :
#                   fraud_rate   count
# card4
# discover            7.728161    6651
# visa                3.475610  384767
# mastercard          3.433095  189217
# american express    2.869837    8328
# card6 fraud rate :
#                  fraud_rate   count
# card6
# credit             6.678480  148986
# debit              2.426251  439938
# charge card        0.000000      15
# debit or credit    0.000000      30

# %%
# hubungan antara card3 (kode negara) dan addr2 (negara billing)
print("--- card3 Value Counts ---")
print(train['card3'].value_counts(dropna=False).head(5))

print("\n--- Correlation between card3=150 and addr2 (billing country) ---")
print(train[train['card3'] == 150]['addr2'].value_counts(dropna=False).head(3))

# fraud rate untuk card yang punya missing value (card2, card3, card5)
print("\n--- Missing values impact on fraud rate ---")
for col in ['card2', 'card3', 'card5']:
    missing_mask = train[col].isnull()
    fr_missing = train.loc[missing_mask, 'isFraud'].mean() * 100
    fr_not_missing = train.loc[~missing_mask, 'isFraud'].mean() * 100
    count_missing = missing_mask.sum()
    print(f"{col} - Missing: {count_missing} ({fr_missing:.2f}% fraud) | Not Missing: {fr_not_missing:.2f}% fraud")

# fraud rate per tier card5 (5 kategori teratas)
print("\n--- card5 (Card Tier/Product Category) Fraud Rate (Top 5) ---")
card5_stats = train.groupby('card5').agg(
    fraud_rate=('isFraud', 'mean'),
    count=('isFraud', 'count')
).sort_values(by='count', ascending=False).head(5)
card5_stats['fraud_rate'] *= 100
print(card5_stats)

# %% [markdown]
# ## Catatan: Fitur Kartu & Rencana Feature Engineering
#
# ### Temuan:
# * **card1** adalah BIN bank (terkonfirmasi dari mapping 1:1 dengan card4). Kardinalitas tinggi (~13.5k nilai unik), tree model akan kesulitan jika pakai nilai mentah.
# * **card2** & **card5** kemungkinan merepresentasikan sub-issuer/cabang dan tier kartu (classic/gold/platinum).
# * **card3** adalah kode negara (mayoritas US, nilai 150.0). Terkonfirmasi karena `card3 == 150.0` hampir selalu dipasangkan dengan `addr2 == 87.0` (US).
# * **card4** (jaringan) & **card6** (tipe) menunjukkan sinyal yang kuat:
#   * Discover punya fraud rate dua kali lipat rata-rata (~7.7% vs ~3.4%).
#   * Kartu kredit punya fraud rate jauh lebih tinggi dari debit (~6.7% vs ~2.4%).
#
# ### Ide Feature Engineering:
# * **Frequency encoding** untuk card1 & card2 agar model bisa memanfaatkan popularitas.
# * **Card ID proxy**: Gabungkan `card1`, `card2`, `card3`, `card5` sebagai identifikasi unik kartu.
# * **Agregasi transaksi**: Hitung mean/std jumlah transaksi berdasarkan Card ID.
# * **Missing flag**: Pertahankan flag missing untuk card2, card3, card5 — missing di sini berkorelasi dengan fraud rate lebih tinggi (~6.7%).

# %% [markdown]
# ## Fitur Email
#
# Menganalisis domain email pembeli dan penerima untuk mengidentifikasi pola fraud.

# %%
for col in ['P_emaildomain', 'R_emaildomain']:
    top_domains = train[col].value_counts().head(10)

    print(f"\n {col} - Top 10 Domain")
    print(top_domains)

    # hitung fraud rate per domain email
    domain_fraud = train.groupby(col)['isFraud'].mean() * 100
    domain_fraud = domain_fraud.loc[top_domains.index]

    print(f'\n Fraud rate by {col} ')
    print(domain_fraud.sort_values(ascending=False))
# Out:
#  P_emaildomain - Top 10 Domain
# P_emaildomain
# gmail.com        228355
# yahoo.com        100934
# hotmail.com       45250
# anonymous.com     36998
# aol.com           28289
# comcast.net        7888
# icloud.com         6267
# outlook.com        5096
# msn.com            4092
# att.net            4033
# Name: count, dtype: int64
#
#  Fraud rate by P_emaildomain
# P_emaildomain
# outlook.com      9.458399
# hotmail.com      5.295028
# gmail.com        4.354185
# icloud.com       3.143450
# comcast.net      3.118661
# anonymous.com    2.321747
# yahoo.com        2.275745
# msn.com          2.199413
# aol.com          2.181060
# att.net          0.743863
# Name: isFraud, dtype: float64
#
#  R_emaildomain - Top 10 Domain
# R_emaildomain
# gmail.com        57147
# hotmail.com      27509
# anonymous.com    20529
# yahoo.com        11842
# aol.com           3701
# outlook.com       2507
# comcast.net       1812
# yahoo.com.mx      1508
# icloud.com        1398
# msn.com            852
# ...

# %%
# konversi kategorikal ke string untuk perbandingan
train['email_match'] = (
    train['P_emaildomain'].astype(str) == train['R_emaildomain'].astype(str)
).fillna(False)

email_match_fraud = train.groupby('email_match')['isFraud'].mean() * 100
print(email_match_fraud)
# Out:
# email_match
# False    2.207009
# True     9.650355
# Name: isFraud, dtype: float64

# %% [markdown]
# ## Count Features (C1–C14)

# %%
c_cols = [f'C{i}' for i in range (1,15)]

print('Count Feature')
print(train[c_cols].describe())
# Out:
# Count Feature
#                   C1             C2             C3             C4  \
# count  590540.000000  590540.000000  590540.000000  590540.000000
# mean       14.092458      15.269734       0.005644       4.092185
# std       133.569016     154.668900       0.150536      68.848457
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       1.000000       0.000000       0.000000
# 50%         1.000000       1.000000       0.000000       0.000000
# 75%         3.000000       3.000000       0.000000       0.000000
# max      4685.000000    5691.000000      26.000000    2253.000000
#
#                   C5             C6             C7             C8  \
# count  590540.000000  590540.000000  590540.000000  590540.000000
# mean        5.571526       9.071082       2.848478       5.144575
# std        25.786976      71.508469      61.727303      95.378571
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# boxplot C1 dan C2 untuk melihat right-skew ekstrem
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# boxplot C1
sns.boxplot(data=train, y='C1', ax=axes[0], color='skyblue')
axes[0].set_title('Boxplot of C1 (Extreme Outliers)')
axes[0].set_ylabel('C1 Value')

# boxplot C2
sns.boxplot(data=train, y='C2', ax=axes[1], color='lightgreen')
axes[1].set_title('Boxplot of C2 (Extreme Outliers)')
axes[1].set_ylabel('C2 Value')

plt.tight_layout()
plt.show()

# pakai skala log agar struktur box (Q1, Median, Q3) terlihat jelas
train['log_C1'] = np.log1p(train['C1'])
train['log_C2'] = np.log1p(train['C2'])

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.boxplot(data=train, y='log_C1', ax=axes[0], color='skyblue')
axes[0].set_title('Boxplot of Log(C1 + 1)')
axes[0].set_ylabel('Log(C1 + 1)')

sns.boxplot(data=train, y='log_C2', ax=axes[1], color='lightgreen')
axes[1].set_title('Boxplot of Log(C2 + 1)')
axes[1].set_ylabel('Log(C2 + 1)')

plt.tight_layout()
plt.show()

# hapus kolom sementara yang sudah tidak dipakai
train.drop(columns=['log_C1', 'log_C2'], inplace=True)

# %%
# korelasi C-features dengan fraud
c_corr = train[c_cols + ['isFraud']].corr()['isFraud'].drop('isFraud').sort_values()

print('c features correlation with isfraud :')
print(c_corr)

# visualisasi
fig, ax = plt.subplots(figsize=(10,6))
c_corr.plot(kind='barh', ax=ax)
ax.set_title('c features correlation with isfraud')
ax.set_xlabel('correlation')
ax.axvline(x=0, color='black', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# c features correlation with isfraud :
# C9    -0.031703
# C5    -0.030754
# C13   -0.011146
# C3    -0.006833
# C14    0.007921
# C6     0.020909
# C11    0.027484
# C7     0.028160
# C10    0.028396
# C4     0.030382
# C1     0.030570
# C12    0.031905
# C8     0.032139
# C2     0.037229
# Name: isFraud, dtype: float64

# %% [markdown]
# ## V-Features (Vesta)
#
# Vesta merekayasa 339 fitur anonim (V1–V339). Banyak yang punya missing value tinggi, tapi yang missing-nya <50% menunjukkan korelasi sedang dengan fraud.

# %%
# V-features (Vesta)
v_cols = [col for col in train.columns if col.startswith('V') and col[1:].isdigit()]

print(f'vesta features : {len(v_cols)} columns')

# hitung persentase missing per V-feature
v_missing = train[v_cols].isnull().sum() / len(train) * 100

print(f'\nMissing Values in V Features:')
print(f' 0% missing: {(v_missing == 0).sum()} columns')
print(f'>0% missing: {(v_missing > 0).sum()} columns')
print(f'>50% missing: {(v_missing > 50).sum()} columns')
print(f'>90% missing: {(v_missing > 90).sum()} columns')
# Out:
# vesta features : 339 columns
#
# Missing Values in V Features:
#  0% missing: 0 columns
# >0% missing: 339 columns
# >50% missing: 159 columns
# >90% missing: 0 columns

# %%
# top V-features berdasarkan korelasi
# hitung korelasi hanya untuk kolom dengan missing < 50%
v_cols_clean = [c for c in v_cols if v_missing[c] < 50]

v_corr = train[v_cols_clean + ['isFraud']].corr()['isFraud'].drop('isFraud').sort_values()

# top korelasi positif dan negatif dengan target
top_positive = v_corr.nlargest(10)
top_negative = v_corr.nsmallest(10)

print('top 10 positive correlation')
print(top_positive)

print('top 10 negative correlation')
print(top_negative)
# Out:
# top 10 positive correlation
# V45    0.281832
# V44    0.260376
# V86    0.251828
# V87    0.251737
# V52    0.239469
# V51    0.223191
# V40    0.212442
# V39    0.203097
# V38    0.199005
# V43    0.198274
# Name: isFraud, dtype: float64
# top 10 negative correlation
# V48   -0.115786
# V49   -0.110920
# V90   -0.110168
# V29   -0.107852
# V91   -0.105453
# V69   -0.104521
# V30   -0.103088
# V70   -0.100900
# V35   -0.077116
# V10   -0.074658
# Name: isFraud, dtype: float64

# %% [markdown]
# ## Ringkasan Temuan
#
# ### Pola Waktu
# - Fraud rate bervariasi per jam — jam tertentu menunjukkan rate lebih tinggi
# - **Implikasi**: Hour-of-day bisa jadi sinyal prediktif yang berguna
#
# ### Fitur Kartu
# - card4 (jaringan) dan card6 (tipe) terkonfirmasi dari nilai string yang terlihat
# - card1 mapping 1:1 ke jaringan kartu — kemungkinan BIN/issuer ID
# - card2, card3, card5 bersifat opaque — butuh encoding
#
# ### Email
# - Domain email mismatch berkorelasi dengan probabilitas fraud
# - **Fitur yang perlu dibuat**: flag kecocokan domain, jenis provider (gratis vs korporat)
#
# ### Langkah Selanjutnya
# - Feature engineering di notebook 07 akan mengekstrak fitur waktu, agregasi kartu, dan fitur email
# - V-features dengan missing tinggi perlu strategi imputasi dari notebook 04
